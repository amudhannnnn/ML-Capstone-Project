# %% [markdown]
# # Person 3 - Data Audit
# Establish dataset dimensions, target balance, and numeric feature availability.

# %%
import pandas as pd
housing = pd.read_csv('housing.csv'); shoppers = pd.read_csv('online_shoppers_intention.csv')
print(housing.shape, shoppers.shape)
print('Missing housing values:', housing.isna().sum().sum())
print(shoppers.Revenue.value_counts())
