# %% [markdown]
# # Person 3 - Evaluation and Visualisation
# Compare the assigned regularised, tree, forest, and support-vector models.

# %%
import pandas as pd
import matplotlib.pyplot as plt
results = pd.DataFrame({'model':['ElasticNet','Decision Tree','Random Forest','SVR','SVC'], 'score':[0,0,0,0,0]})
display(results)
results.plot.bar(x='model', y='score', legend=False, title='Person 3 model comparison'); plt.xticks(rotation=25); plt.tight_layout(); plt.show()
